# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
books=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Books.csv")
users=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Users.csv")
ratings=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Ratings.csv")

# %%
books.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author  Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                 2002     Oxford University Press
# 1  Richard Bruce Wright                 2001       HarperFlamingo Canada
# 2          Carlo D'Este                 1991             HarperPerennial
# 3      Gina Bari Kolata                 1999        Farrar Straus Giroux
# 4       E. J. W. Barber                 1999  W. W. Norton &amp; Company
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# ...

# %%
users.head()
# Out:
#    User-ID                            Location   Age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN

# %%
ratings.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6

# %%
print(books.shape)
print(users.shape)
print(ratings.shape)
# Out:
# (171541, 8)
# (278858, 3)
# (1149780, 3)

# %%
##lets check for the mising values 
books.isnull().sum()
# Out:
# ISBN                   0
# Book-Title             0
# Book-Author            0
# Year-Of-Publication    0
# Publisher              2
# Image-URL-S            0
# Image-URL-M            0
# Image-URL-L            1
# dtype: int64

# %%
users.isnull().sum()
# Out:
# User-ID          0
# Location         0
# Age         110762
# dtype: int64

# %%
ratings.isnull().sum()
# Out:
# User-ID        0
# ISBN           0
# Book-Rating    0
# dtype: int64

# %%
books.duplicated().sum()
# Out:
# 0

# %%
ratings.duplicated().sum()
# Out:
# 0

# %%
users.duplicated().sum()
# Out:
# 0

# %%
## 
col_object=books.select_dtypes(include="object").columns

# %%
col_object
# Out:
# Index(['ISBN', 'Book-Title', 'Book-Author', 'Publisher', 'Image-URL-S',
#        'Image-URL-M', 'Image-URL-L'],
#       dtype='object')

# %% [markdown]
# ### For recommendation system we can use Three types of Model .
# ###1. Cluster based Model
# ###2. Linear Regression Model By calculationg a Particular Score.
# ###3. Bayesian Networks , which will use the conditional Probability.

# %%
##Lets See the data distribution 
books_ratings=ratings.merge(books, on='ISBN')

# %% [markdown]
# ## Popularity Based Recommender System

# %%
books_ratings.head()
# Out:
#    User-ID        ISBN  Book-Rating            Book-Title Book-Author  \
# 0   276725  034545104X            0  Flesh Tones: A Novel  M. J. Rose
# 1     2313  034545104X            5  Flesh Tones: A Novel  M. J. Rose
# 2     6543  034545104X            0  Flesh Tones: A Novel  M. J. Rose
# 3     8680  034545104X            5  Flesh Tones: A Novel  M. J. Rose
# 4    10314  034545104X            9  Flesh Tones: A Novel  M. J. Rose
#
#    Year-Of-Publication         Publisher  \
# 0                 2002  Ballantine Books
# 1                 2002  Ballantine Books
# 2                 2002  Ballantine Books
# 3                 2002  Ballantine Books
# 4                 2002  Ballantine Books
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/034545104X.0...
# 1  http://images.amazon.com/images/P/034545104X.0...
# 2  http://images.amazon.com/images/P/034545104X.0...
# 3  http://images.amazon.com/images/P/034545104X.0...
# ...

# %%
books_ratings.shape
# Out:
# (904113, 10)

# %%
books_ratings.groupby('Book-Title').count() ## Because the Single book can have Multiple ISBN Numbers
# Out:
#                                                     User-ID  ISBN  \
# Book-Title
#  A Light in the Storm: The Civil War Diary of A...        4     4
#  Apple Magic (The Collector's series)                     1     1
#  Beyond IBM: Leadership Marketing and Finance f...        1     1
#  Dark Justice                                             1     1
#  Earth Prayers From around the World: 365 Praye...       10    10
# ...                                                     ...   ...
# Ã?Â?bermorgen.                                            1     1
# Ã?Â?lpiraten.                                             2     2
# Ã?Â?rger mit Produkt X. Roman.                            4     4
# Ã?Â?stlich der Berge.                                     3     3
# Ã?Â?thique en toc                                         2     2
#
#                                                     Book-Rating  Book-Author  \
# Book-Title
# ...

# %% [markdown]
# ##### Rest_index Convert a series intpo the Dataframe By providing the indexing

# %%
nums_rating_df=books_ratings.groupby('Book-Title').count()['Book-Rating'].reset_index()

# %% [markdown]
# ##### Here Basically We are counting the number of ratings on the particular Books

# %%
nums_rating_df.rename(columns={'Book-Rating': 'num_ratings'}, inplace=True)
nums_rating_df
# Out:
#                                                Book-Title  num_ratings
# 0        A Light in the Storm: The Civil War Diary of ...            4
# 1                    Apple Magic (The Collector's series)            1
# 2        Beyond IBM: Leadership Marketing and Finance ...            1
# 3                                            Dark Justice            1
# 4        Earth Prayers From around the World: 365 Pray...           10
# ...                                                   ...          ...
# 154232                                     Ã?Â?bermorgen.            1
# 154233                                      Ã?Â?lpiraten.            2
# 154234                     Ã?Â?rger mit Produkt X. Roman.            4
# 154235                              Ã?Â?stlich der Berge.            3
# 154236                                  Ã?Â?thique en toc            2
#
# [154237 rows x 2 columns]

# %%
## Average ratings
avg_Bookrating=books_ratings.groupby('Book-Title')['Book-Rating'].mean().reset_index()

# %%
avg_Bookrating.rename(columns={'Book-Rating':'avg_rating'}, inplace=True)
avg_Bookrating
# Out:
#                                                Book-Title  avg_rating
# 0        A Light in the Storm: The Civil War Diary of ...    2.250000
# 1                    Apple Magic (The Collector's series)    0.000000
# 2        Beyond IBM: Leadership Marketing and Finance ...    0.000000
# 3                                            Dark Justice   10.000000
# 4        Earth Prayers From around the World: 365 Pray...    5.000000
# ...                                                   ...         ...
# 154232                                     Ã?Â?bermorgen.    0.000000
# 154233                                      Ã?Â?lpiraten.    0.000000
# 154234                     Ã?Â?rger mit Produkt X. Roman.    5.250000
# 154235                              Ã?Â?stlich der Berge.    2.666667
# 154236                                  Ã?Â?thique en toc    4.000000
#
# [154237 rows x 2 columns]

# %%
## Lets Create a Popularity rating
Popular_books=nums_rating_df.merge(avg_Bookrating, on='Book-Title')
Popular_books
# Out:
#                                                Book-Title  num_ratings  \
# 0        A Light in the Storm: The Civil War Diary of ...            4
# 1                    Apple Magic (The Collector's series)            1
# 2        Beyond IBM: Leadership Marketing and Finance ...            1
# 3                                            Dark Justice            1
# 4        Earth Prayers From around the World: 365 Pray...           10
# ...                                                   ...          ...
# 154232                                     Ã?Â?bermorgen.            1
# 154233                                      Ã?Â?lpiraten.            2
# 154234                     Ã?Â?rger mit Produkt X. Roman.            4
# 154235                              Ã?Â?stlich der Berge.            3
# 154236                                  Ã?Â?thique en toc            2
#
#         avg_rating
# 0         2.250000
# 1         0.000000
# 2         0.000000
# 3        10.000000
# ...

# %%
Popular_books.sort_values(by=['num_ratings','avg_rating'], ascending=[False,False])
# Out:
#                                                Book-Title  num_ratings  \
# 150423                                        Wild Animus         2502
# 125648                          The Lovely Bones: A Novel         1295
# 117027                                  The Da Vinci Code          897
# 3414                                      A Painted House          834
# 127607                         The Nanny Diaries: A Novel          828
# ...                                                   ...          ...
# 154220  Ã?ber Alfred Andersch (Diogenes-Taschenbuch ; 53)            1
# 154221  Ã?ber den Wunsch, sich wohlzufÃ¼hlen: Geschichten            1
# 154227               Ã?Â?ber den letzten Stand der Dinge.            1
# 154230                             Ã?Â?ber die Regierung.            1
# 154232                                     Ã?Â?bermorgen.            1
#
#         avg_rating
# 150423    1.019584
# 125648    4.468726
# 117027    4.647715
# 3414      3.220624
# ...

# %%
Popular_books=Popular_books[Popular_books['num_ratings']>=250]

# %%
Popular_df=Popular_books.sort_values(['avg_rating'], ascending=False).head(50)

# %%
Popular_df=Popular_df.merge(books, on='Book-Title')

# %%
Popular_df
# Out:
#                                             Book-Title  num_ratings  \
# 0    Harry Potter and the Prisoner of Azkaban (Book 3)          428
# 1    Harry Potter and the Prisoner of Azkaban (Book 3)          428
# 2    Harry Potter and the Prisoner of Azkaban (Book 3)          428
# 3         Harry Potter and the Goblet of Fire (Book 4)          387
# 4         Harry Potter and the Goblet of Fire (Book 4)          387
# ..                                                 ...          ...
# 168  Hard Eight : A Stephanie Plum Novel (A Stephan...          268
# 169                            A Prayer for Owen Meany          413
# 170                            A Prayer for Owen Meany          413
# 171   The Vampire Lestat (Vampire Chronicles, Book II)          301
# 172       White Oleander : A Novel (Oprah's Book Club)          356
#
#      avg_rating        ISBN      Book-Author  Year-Of-Publication  \
# 0      5.852804  0439136350    J. K. Rowling                 1999
# ...

# %%
### Their are Some duplicate Books also 
Popular_df.drop_duplicates('Book-Title', inplace=True)

# %%
Popular_df.shape
# Out:
# (50, 10)

# %%
Popular_df
# Out:
#                                             Book-Title  num_ratings  \
# 0    Harry Potter and the Prisoner of Azkaban (Book 3)          428
# 3         Harry Potter and the Goblet of Fire (Book 4)          387
# 5       Harry Potter and the Sorcerer's Stone (Book 1)          274
# 8    Harry Potter and the Order of the Phoenix (Boo...          346
# 11    Harry Potter and the Chamber of Secrets (Book 2)          556
# 14   The Hobbit : The Enchanting Prelude to The Lor...          281
# 15   The Fellowship of the Ring (The Lord of the Ri...          368
# 24   Harry Potter and the Sorcerer's Stone (Harry P...          575
# 26      The Two Towers (The Lord of the Rings, Part 2)          258
# 35                               To Kill a Mockingbird          506
# 41                                   The Da Vinci Code          897
# 45                  The Five People You Meet in Heaven          427
# 46                              The Catcher in the Rye          448
# ...

# %% [markdown]
# #### Logic that we are going to use for the recommender system will be to focus on the rating values of the Experience Users like those readed atleast 200-250 books ,That will be perform Rowwise That means They have enough Knowledge of Context <br> <br> Only Consider that Books which have Atleast 50 ratings

# %% [markdown]
# # **Collaborative Filtering Based Recommender System**

# %%
## Completing the First Condition 
x=books_ratings.groupby('User-ID')['Book-Rating'].count()>200
x[x]
# Out:
# User-ID
# 254       True
# 2276      True
# 2766      True
# 2977      True
# 3363      True
#           ...
# 274301    True
# 274308    True
# 275970    True
# 277427    True
# 278418    True
# Name: Book-Rating, Length: 701, dtype: bool

# %%
Experienced_Readers=x[x].index

# %%
## Now we are trying to fetch all the details of the Experienced Users 
z=books_ratings['User-ID'].isin(Experienced_Readers)
Readers_details=books_ratings[z]

# %%
Readers_details
# Out:
#         User-ID        ISBN  Book-Rating  \
# 2          6543  034545104X            0
# 5         23768  034545104X            0
# 7         28523  034545104X            0
# 15        77940  034545104X            0
# 16        81977  034545104X            0
# ...         ...         ...          ...
# 903871   275970  1880837927            0
# 903872   275970  188717897X            0
# 903873   275970  1888889047            0
# 903874   275970  1931868123            0
# 903875   275970  3411086211           10
#
#                                                Book-Title  \
# 2                                    Flesh Tones: A Novel
# 5                                    Flesh Tones: A Novel
# 7                                    Flesh Tones: A Novel
# 15                                   Flesh Tones: A Novel
# 16                                   Flesh Tones: A Novel
# ...                                                   ...
# ...

# %%
## Considering Only Those Books Which have a decent Number of Count
Books_Ratings_count=Readers_details.groupby('Book-Title').count()['Book-Rating'].reset_index()

# %%
Books_Ratings_count.columns
# Out:
# Index(['Book-Title', 'Book-Rating'], dtype='object')

# %%
# y=Books_Ratings_count['Book-Rating']
# # X=Books_Ratings_count.drop(['Book-Rating'], axis=1)
# x=Books_Ratings_count['Book-Title']

# %%
# plt.scatter(x,y)
# plt.show()

# %%
###Hence on Visyualizing the data of rating counts on each Book , The average value looks 50 through scatter plot 
z=Readers_details.groupby('Book-Title').count()['Book-Rating']>=50
famous_books=z[z].index
finals_ratings=Readers_details[Readers_details['Book-Title'].isin(famous_books)]
##FinalReaders=Readers_details[['Book-Title'].isin(FinalReaders)]

# %%
Books_Ratings_count
# Out:
#                                                Book-Title  Book-Rating
# 0        A Light in the Storm: The Civil War Diary of ...            2
# 1                    Apple Magic (The Collector's series)            1
# 2        Beyond IBM: Leadership Marketing and Finance ...            1
# 3                                            Dark Justice            1
# 4        Earth Prayers From around the World: 365 Pray...            2
# ...                                                   ...          ...
# 103692                  Ã?ngeles fugaces (Falling Angels)            1
# 103693  Ã?Â?ber die Pflicht zum Ungehorsam gegen den S...            1
# 103694                                      Ã?Â?lpiraten.            1
# 103695                              Ã?Â?stlich der Berge.            1
# 103696                                  Ã?Â?thique en toc            1
#
# [103697 rows x 2 columns]

# %%
finals_ratings.drop_duplicates()
# Out:
#         User-ID        ISBN  Book-Rating              Book-Title  \
# 61       278418  0446520802            0            The Notebook
# 63         3363  0446520802            0            The Notebook
# 64         7158  0446520802           10            The Notebook
# 67        11676  0446520802           10            The Notebook
# 72        23768  0446520802            6            The Notebook
# ...         ...         ...          ...                     ...
# 899898   266865  0531001725           10  The Catcher in the Rye
# 901014   269566  0670809381            0                  Echoes
# 901837   271284  0440910927            0           The Rainmaker
# 902129   271705  B0001PIOX4            0          Fahrenheit 451
# 903858   275970  1586210661            9  Me Talk Pretty One Day
#
#                   Book-Author  Year-Of-Publication                Publisher  \
# 61            Nicholas Sparks                 1996             Warner Books
# ...

# %%
## No Duplicates

pt=finals_ratings.pivot_table(index='Book-Title', columns='User-ID', values='Book-Rating')

# %%
pt.shape
# Out:
# (631, 699)

# %%
## Lets Fill Null values 
pt.fillna(0, inplace=True)

# %% [markdown]
# ##### pt is a Pivot dataframe in which Book-Title is used as Row index and Users Id as Columns and Value is a rating given by that User to that Book

# %%
pt
# Out:
# User-ID                                             254     2276    2766    \
# Book-Title
# 1984                                                   9.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0    10.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     7.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# ...

# %% [markdown]
# ## Basically Going To Measures the Distances of rating Given by Multiple user for a particular Book
#
# #### we have Converted each and every book as a Vector
#
# #### we would calculated the Eculidean Distance of each and Every Book
# #### Basically using Similarity Measures

# %%
from sklearn.metrics.pairwise import cosine_similarity
similarity_scores=cosine_similarity(pt)

# %%
similarity_scores
# Out:
# array([[1.        , 0.10976162, 0.01343813, ..., 0.12609053, 0.07650128,
#         0.04583912],
#        [0.10976162, 1.        , 0.25697499, ..., 0.07654542, 0.17243366,
#         0.1495673 ],
#        [0.01343813, 0.25697499, 1.        , ..., 0.04819434, 0.05220974,
#         0.11642391],
#        ...,
#        [0.12609053, 0.07654542, 0.04819434, ..., 1.        , 0.07085128,
#         0.0200112 ],
#        [0.07650128, 0.17243366, 0.05220974, ..., 0.07085128, 1.        ,
#         0.1081564 ],
#        [0.04583912, 0.1495673 , 0.11642391, ..., 0.0200112 , 0.1081564 ,
#         1.        ]])

# %%
def recommend(book_name):
  #index fetch
  index= np.where(pt.index==book_name)[0][0]
  similar_items=sorted(list(enumerate(similarity_scores[index])), key=lambda x:x[1], reverse=True)[1:6]
  
  for i in similar_items:
    print(pt.index[i[0]])
  # return suggestions

# %%
np.where(pt.index=="A Bend in the Road")[0] ## It is eturnm the whole Row
# Out:
# array([4])

# %%
np.where(pt.index=="A Bend in the Road")[0][0]
# Out:
# 4

# %%
## By enumeration each Distance measures of Book with another Book combine with its index Position
sorted(list(enumerate(similarity_scores[0])), key=lambda x:x[1], reverse=True)[1:6]
## Reverse=true Helps to find the Most Similar elements
# Out:
# [(482, 0.27867978266115323),
#  (43, 0.255673418254783),
#  (565, 0.25339729192227956),
#  (72, 0.24074724120859248),
#  (488, 0.23558117322586175)]

# %%
pt.index ## Here Books Titles are Indexes
# Out:
# Index(['1984', '1st to Die: A Novel', '2nd Chance', '4 Blondes',
#        'A Bend in the Road', 'A Case of Need',
#        'A Child Called \It\": One Child's Courage to Survive"',
#        'A Civil Action', 'A Fine Balance',
#        'A Heartbreaking Work of Staggering Genius',
#        ...
#        'Winter Moon', 'Winter Solstice', 'Wish You Well', 'Without Remorse',
#        'Wuthering Heights', 'Year of Wonders', 'You Belong To Me',
#        'Zen and the Art of Motorcycle Maintenance: An Inquiry into Values',
#        'Zoya', '\O\" Is for Outlaw"'],
#       dtype='object', name='Book-Title', length=631)

# %%
recommend("Message in a Bottle")
# Out:
# A Walk to Remember
# Nights in Rodanthe
# The Mulberry Tree
# River's End
# All I Really Need to Know

# %%
recommend('The Da Vinci Code')
# Out:
# Angels &amp; Demons
# Saving Faith
# The Sweet Potato Queens' Book of Love
# Touching Evil
# The Lovely Bones: A Novel

# %%
import pickle
pickle.dump(Popular_df,open('popular.pkl', 'wb')) ## wb is used for the Byte stream generation

# %%
np.where(Popular_df['Book-Title']=="The Color Purple")
# Out:
# (array([39]),)

# %%
Popular_df.iloc[38][7]
# Out:
# 'http://images.amazon.com/images/P/0842329129.01.THUMBZZZ.jpg'

# %%
def recommend(book_name):
  #index fetch
  index= np.where(pt.index==book_name)[0][0]
  similar_items=sorted(list(enumerate(similarity_scores[index])), key=lambda x:x[1], reverse=True)[1:6]
  
  ## Similar Items is a list of similar books 
  data=[]
  for i in similar_items:
    # print(pt.index[i[0]]) ## it is returning the index of the item
    item=[]
    ## 0th column will give the Book-Title
    temp_df=books[books['Book-Title']==pt.index[i[0]]]
    ## Preparing the data of that similar book, to display it on a webpage 
    Ratings=avg_Bookrating[avg_Bookrating['Book-Title']==pt.index[i[0]]]
## extend add as a element of the existing list and where append add the list of that element to the existing  list 
    item.extend(list(temp_df.drop_duplicates('Book-Title')['Book-Title'].values))
    item.extend(list(temp_df.drop_duplicates('Book-Title')['Book-Author'].values))
    item.extend(list(temp_df.drop_duplicates('Book-Title')['Image-URL-M'].values))
    item.extend(list(Ratings.drop_duplicates('Book-Title')['avg_rating'].values))
    
    data.append(item)
  return data

# %%
recommend("1984")[3][0] ## data is the list of item list
# Out:
# 'Brave New World'

# %% [markdown]
# #### Recommend Function is using three dataframes , Books,similarity_scores, pt<br> so we need to export them

# %%
pickle.dump(pt,open('pt.pkl', 'wb'))
pickle.dump(similarity_scores,open('similarity_scores.pkl', 'wb'))
pickle.dump(books, open('books.pkl', 'wb'))

# %%
pickle.dump(avg_Bookrating,open('avg_Bookrating.pkl','wb'))
